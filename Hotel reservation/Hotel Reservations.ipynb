# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Hotel_Reservations.csv')

# %%
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
data.shape
# Out:
# (36275, 19)

# %%
data.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),vmin=-1,vmax=1,center=0,annot=True,data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - no_of_previous_bookings_not_canceled is highly correlated with repeated_guest

# %%
cols= data.columns
cols
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
data.drop(['Booking_ID'],axis=1,inplace=True)

# %%
plt.figure(figsize=(12,11))
sns.pairplot(data[['avg_price_per_room','lead_time', 'arrival_month', 'booking_status']],hue='booking_status')

# %%
sns.countplot(data['booking_status'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='booking_status', ylabel='count'>

# %%
data['booking_status'].value_counts()
# Out:
# Not_Canceled    24390
# Canceled        11885
# Name: booking_status, dtype: int64

# %%
numerical_features = data.select_dtypes(['float64','int64'])
numerical_features.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests'],
#       dtype='object')

# %%
categorical_features = data.select_dtypes(['object'])
categorical_features.columns
# Out:
# Index(['type_of_meal_plan', 'room_type_reserved', 'market_segment_type',
#        'booking_status'],
#       dtype='object')

# %% [markdown]
# **Analysis on Arrival year**

# %%
data['arrival_year'].value_counts()
# Out:
# 2018    29761
# 2017     6514
# Name: arrival_year, dtype: int64

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='arrival_year',data=data,hue='booking_status',palette='autumn')
# Out:
# <AxesSubplot:xlabel='arrival_year', ylabel='count'>

# %% [markdown]
# - Year2018 bookings has max bookings

# %% [markdown]
# **Analysis on arrival month**

# %%
data['arrival_month'].value_counts()
# Out:
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: arrival_month, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.countplot(data['arrival_month'],hue=data['booking_status'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='arrival_month', ylabel='count'>

# %%
month = {1:'Jan',2:'Feb',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
for i in range(1,13):
    plt.figure(figsize=(8,5))
    sns.set_style("darkgrid")
    
    sns.countplot(data=data[data['arrival_month']==i],x='market_segment_type',hue='booking_status',palette='gnuplot')
    plt.title(f'booking status in {month[i]}')
    plt.xlabel('market segment')
    plt.ylabel('count')

# %% [markdown]
# - During the month of October,November,December bookings are up.
# - Cancellations are less in the month November ,December & January

# %%
data['market_segment_type'].value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='market_segment_type',hue='booking_status',data=data)
# Out:
# <AxesSubplot:xlabel='market_segment_type', ylabel='count'>

# %% [markdown]
# - Online booking are high compared to other market_segment_type
# - Corporate & Aviation are having almost zero booking_cancellation

# %%
data['required_car_parking_space'].value_counts()
# Out:
# 0    35151
# 1     1124
# Name: required_car_parking_space, dtype: int64

# %%
label=["Parking_required","No_parking_required"]
size = data[data['required_car_parking_space']==1]['booking_status'].value_counts()
plt.pie(size,explode=[0,0.1],labels=label)
plt.legend(bbox_to_anchor=(1.24, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
data[data['required_car_parking_space']==1]['booking_status'].value_counts()
# Out:
# Not_Canceled    1010
# Canceled         114
# Name: booking_status, dtype: int64

# %%
data['room_type_reserved'].value_counts()
# Out:
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: room_type_reserved, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.histplot(x='room_type_reserved',data=data,hue='booking_status')
# Out:
# <AxesSubplot:xlabel='room_type_reserved', ylabel='Count'>

# %% [markdown]
# - Room_type 1 is most prefered by the customers followed by
#   Room_type 4

# %%
data['lead_time'].value_counts()
# Out:
# 0      1297
# 1      1078
# 2       643
# 3       630
# 4       628
#        ...
# 300       1
# 353       1
# 328       1
# 352       1
# 351       1
# Name: lead_time, Length: 352, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(y='lead_time',data=data,x='booking_status')
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='lead_time'>

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x='lead_time',data=data,hue='booking_status')
plt.plot()
# Out:
# []

# %% [markdown]
# **MODEL BUILDING**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
object=['type_of_meal_plan','room_type_reserved','market_segment_type']
label=LabelEncoder()
for col in object:
    X[col]=label.fit_transform(X[col])
X
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
y=label.fit_transform(y)
pd.DataFrame(y,columns=['booking_status'])
# Out:
#        booking_status
# 0                   1
# 1                   1
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 36270               1
# 36271               0
# 36272               1
# 36273               0
# 36274               1
#
# [36275 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=44)
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (25392, 17)
# X_test shape is  (10883, 17)
# y_train shape is  (25392,)
# y_test shape is  (10883,)

# %% [markdown]
# **Logistic Regression**

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7930717633005605

# %%
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.58      0.64      3541
#            1       0.81      0.90      0.85      7342
#
#     accuracy                           0.79     10883
#    macro avg       0.77      0.74      0.75     10883
# weighted avg       0.79      0.79      0.79     10883

# %% [markdown]
# **Random Forest**

# %%
rf = RandomForestClassifier(n_estimators=100,criterion='gini',
    max_depth=20)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20)

# %%
y_predd = rf.predict(X_test)

# %%
accuracy_score(y_test,y_predd)
# Out:
# 0.8994762473582651

# %%
rf = classification_report(y_test,y_predd)
print(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84      3541
#            1       0.91      0.94      0.93      7342
#
#     accuracy                           0.90     10883
#    macro avg       0.89      0.88      0.88     10883
# weighted avg       0.90      0.90      0.90     10883

# %% [markdown]
# *Got 90% accuracy through random forest classifier model*

# %%
import pickle

# %%
filename = 'trained_model.sav'
pickle.dump(rf, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('trained_model.sav', 'rb'))
